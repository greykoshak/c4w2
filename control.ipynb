# %% [markdown]
# # Визуализация датасета

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('Fifa/CompleteDataset.csv')
df.head(14)
# Out:
#     Unnamed: 0               Name  Age  \
# 0            0  Cristiano Ronaldo   32
# 1            1           L. Messi   30
# 2            2             Neymar   25
# 3            3          L. Suárez   30
# 4            4           M. Neuer   31
# 5            5     R. Lewandowski   28
# 6            6             De Gea   26
# 7            7          E. Hazard   26
# 8            8           T. Kroos   27
# 9            9         G. Higuaín   29
# 10          10       Sergio Ramos   31
# 11          11       K. De Bruyne   26
# 12          12        T. Courtois   25
# 13          13         A. Sánchez   28
#
#                                               Photo Nationality  \
# 0    https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1   https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2   https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3   https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# ...

# %%
df.groupby('Nationality').head(10)[['Name', 'Nationality', 'Club', 'Overall']]
# Out:
#                     Name        Nationality                    Club  Overall
# 0      Cristiano Ronaldo           Portugal          Real Madrid CF       94
# 1               L. Messi          Argentina            FC Barcelona       93
# 2                 Neymar             Brazil     Paris Saint-Germain       92
# 3              L. Suárez            Uruguay            FC Barcelona       92
# 4               M. Neuer            Germany        FC Bayern Munich       92
# 5         R. Lewandowski             Poland        FC Bayern Munich       91
# 6                 De Gea              Spain       Manchester United       90
# 7              E. Hazard            Belgium                 Chelsea       90
# 8               T. Kroos            Germany          Real Madrid CF       90
# 9             G. Higuaín          Argentina                Juventus       90
# 10          Sergio Ramos              Spain          Real Madrid CF       90
# ...
